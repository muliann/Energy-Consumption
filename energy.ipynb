# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data= pd.read_csv("data.csv")
data
# Out:
#         id        Date  Consumption     Wind   Solar  Wind+Solar
# 0        0    1/1/2006   1069.18400      NaN     NaN         NaN
# 1        1    1/2/2006   1380.52100      NaN     NaN         NaN
# 2        2    1/3/2006   1442.53300      NaN     NaN         NaN
# 3        3    1/4/2006   1457.21700      NaN     NaN         NaN
# 4        4    1/5/2006   1477.13100      NaN     NaN         NaN
# ...    ...         ...          ...      ...     ...         ...
# 4378  4378  12/27/2017   1263.94091  394.507  16.530     411.037
# 4379  4379  12/28/2017   1299.86398  506.424  14.162     520.586
# 4380  4380  12/29/2017   1295.08753  584.277  29.854     614.131
# 4381  4381  12/30/2017   1215.44897  721.247   7.467     728.714
# 4382  4382  12/31/2017   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4383 non-null   int64
#  1   Date         4383 non-null   object
#  2   Consumption  4383 non-null   float64
#  3   Wind         2920 non-null   float64
#  4   Solar        2188 non-null   float64
#  5   Wind+Solar   2187 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 205.6+ KB

# %%
data.tail()
# Out:
#         id        Date  Consumption     Wind   Solar  Wind+Solar
# 4378  4378  12/27/2017   1263.94091  394.507  16.530     411.037
# 4379  4379  12/28/2017   1299.86398  506.424  14.162     520.586
# 4380  4380  12/29/2017   1295.08753  584.277  29.854     614.131
# 4381  4381  12/30/2017   1215.44897  721.247   7.467     728.714
# 4382  4382  12/31/2017   1107.11488  721.176  19.980     741.156

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4383, step=1)

# %%
data.columns
# Out:
# Index(['id', 'Date', 'Consumption', 'Wind', 'Solar', 'Wind+Solar'], dtype='object')

# %%
data.shape
# Out:
# (4383, 6)

# %%
X=data.loc[:1460,["id","Consumption","Wind","Solar", "Wind+Solar"]]
Y1=data.loc[:2190,[ "Wind+Solar"]]
Y2=data.loc[:2190,[ "Solar"]]
Y3=data.loc[:1460,[ "Wind"]]
Y1.shape,y2.shape,y3.shape,x.shape
# Out:
# ((2191, 1), (2187, 1), (2187, 1), (2187, 4))

# %%
data.isnull().sum()
# Out:
# id                0
# Date              0
# Consumption       0
# Wind           1463
# Solar          2195
# Wind+Solar     2196
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# id             0
# Date           0
# Consumption    0
# Wind           0
# Solar          0
# Wind+Solar     0
# dtype: int64

# %%
data.hist()
plt.show()

# %%
x=data.loc[:,["Consumption","Wind","Solar", "Wind+Solar"]]
y1=data.loc[:,[ "Wind+Solar"]]
y2=data.loc[:,[ "Solar"]]
y3=data.loc[:,[ "Wind"]]
y1.shape,y2.shape,y3.shape,x.shape
# Out:
# ((2187, 1), (2187, 1), (2187, 1), (2187, 4))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y1_train,y1_test = train_test_split(x,y1,test_size=0.4, random_state=0)
x_train.shape,x_test.shape,y1_train.shape,y1_test.shape
# Out:
# ((1312, 4), (875, 4), (1312, 1), (875, 1))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y2_train,y2_test = train_test_split(x,y2,test_size=0.4, random_state=0)
x_train.shape,x_test.shape,y2_train.shape,y2_test.shape
# Out:
# ((1312, 4), (875, 4), (1312, 1), (875, 1))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y3_train,y3_test = train_test_split(x,y3,test_size=0.4, random_state=0)
x_train.shape,x_test.shape,y3_train.shape,y3_test.shape
# Out:
# ((1312, 4), (875, 4), (1312, 1), (875, 1))

# %%
from sklearn import linear_model as lm 
import sklearn.metrics as sm 
model=lm.LinearRegression()
model.fit(x_train,y1_train)
pred=model.predict(x_test)
print(sm.r2_score(y1_test,pred))
# Out:
# 1.0

# %%
from sklearn import linear_model as lm 
import sklearn.metrics as sm 
model=lm.LinearRegression()
model.fit(x_train,y1_train)
pred=model.predict(x_test)
print(sm.r2_score(y1_test,pred))
# Out:
# 1.0

# %%
from sklearn import linear_model as lm 
import sklearn.metrics as sm 
model=lm.LinearRegression()
model.fit(x_train,y1_train)
pred=model.predict(x_test)
print(sm.r2_score(y1_test,pred))
# Out:
# 1.0

# %%
y2.plot()
plt.show()

# %%
y1.plot()
plt.show()

# %%
y3.plot()
plt.show()
